# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
dfx=pd.read_csv("./Documents/machine-learning-online-2018/Datasets/xdata.csv")
dfy=pd.read_csv("./Documents/machine-learning-online-2018/Datasets/ydata.csv")

# %%
X=dfx.values
Y=dfy.values

X= X[:,1:]
Y= Y[:,1:].reshape((-1))

print(X.shape)
print(Y.shape)
# Out:
# (399, 2)
# (399,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
query_x=np.array([2,3])
plt.scatter(X[:,0],X[:,1],c=Y)
plt.scatter(query_x[0],query_x[1],color='red')
plt.show()

# %%
def dist(x1,x2):
    return np.sqrt(sum((x1-x2)**2))

# Test Time 
def knn(X,Y,queryPoint,k=5):
    
    vals = []
    m = X.shape[0]
    
    for i in range(m):
        d = dist(queryPoint,X[i])
        vals.append((d,Y[i]))
        
    
    vals = sorted(vals)
    # Nearest/First K points
    vals = vals[:k]
    
    vals = np.array(vals)
    
    print(vals)
    new_vals=np.unique(vals[:,1],return_counts=True)
    print(new_vals)
    index=new_vals[1].argmax()
    pred=new_vals[0][index]
    return pred

# %%
x = knn(X,Y,query_x)
print(x)
# Out:
# [[0.11937695 0.        ]
#  [0.24392799 1.        ]
#  [0.24435617 0.        ]
#  [0.32750158 0.        ]
#  [0.44941874 1.        ]]
# (array([0., 1.]), array([3, 2]))
# 0.0
